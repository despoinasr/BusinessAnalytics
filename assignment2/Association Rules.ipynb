# %% [markdown]
# # Association Rules
#
# This method tries to find rules that show how items are usually paired together. In our case, we try to find rules about how points of interest are usually visited together.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import numpy as np

# %% [markdown]
# ### Data

# %%
walkins = pd.read_csv('Aueb Dmst Assignment Data\walkins.csv', dtype = str)
users = pd.read_csv('Aueb Dmst Assignment Data\\users.csv', dtype = str)
pois = pd.read_csv('Aueb Dmst Assignment Data\pois.csv', dtype = str)
categories = pd.read_csv('Aueb Dmst Assignment Data\categories.csv', dtype = str)

# %%
categories.rename(columns= {'id': 'category_id'}, inplace = True)
pois_categories = pd.merge(pois[['id', 'category_id']],
                           categories,
                           how = 'left',
                           on = 'category_id')

# %%
pois_categories.rename(columns= {'id': 'poi_id'}, inplace = True)
visits = pd.merge(walkins,
                  pois_categories[['poi_id', 'title']],
                  how = 'left',
                  on = 'poi_id')

# %%
user_cons = pd.read_excel('user_cons.xlsx', dtype = str)

# %% [markdown]
# ### Analysis

# %% [markdown]
# * **Confidence**: the probability that a transaction X also contains the object Y.
# * **Lift**: an indication of whether a rule can be considered representative of the data to be used in the decision-making process.

# %% [markdown]
# #### Analysis 1: Per Day & Per User between Categories of Points of Interest
#
# We try to find if there is an association between the categories of points of interest a user visits during the same day.

# %%
visits['code'] = visits['user_id'] + visits['created']
data = visits[['code', 'title', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data = data.groupby(by=['code', 'title']).count().reset_index()
data['sum'] = 1

# %%
perday = data.groupby(['code', 'title'])['sum'].sum().unstack().reset_index().fillna(0).set_index('code')

# %%
frequent_itemsets = apriori(perday, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.8)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules.head(15)
# Out:
#             antecedents    consequents  antecedent support  \
# 31          (Pet Store)  (Supermarket)            0.036030
# 3              (Bakery)  (Supermarket)            0.052697
# 17  (Electronics Store)  (Supermarket)            0.046620
# 43      (Women's Store)  (Supermarket)            0.092467
# 33         (Shoe Store)  (Supermarket)            0.043042
# 19                (Gym)  (Supermarket)            0.044121
# 21         (Home Store)  (Supermarket)            0.066613
# 11     (Clothing Store)  (Supermarket)            0.072186
# 29             (Museum)  (Supermarket)            0.032327
# 27      (Metro Station)  (Supermarket)            0.104585
# 35      (Shopping Mall)  (Supermarket)            0.096997
# 15    (Cultural Center)  (Supermarket)            0.070191
# 41         (University)  (Supermarket)            0.064204
# 39         (University)       (Square)            0.064204
# 24      (Metro Station)       (Square)            0.104585
#
#     consequent support   support  confidence      lift  leverage  conviction
# 31            0.397681  0.014168    0.393214  0.988767 -0.000161    0.992638
# 3             0.397681  0.019597    0.371887  0.935139 -0.001359    0.958934
# 17            0.397681  0.017296    0.370999  0.932906 -0.001244    0.957581
# 43            0.397681  0.032291    0.349213  0.878123 -0.004482    0.925524
# 33            0.397681  0.014851    0.345029  0.867604 -0.002266    0.919613
# 19            0.397681  0.014941    0.338631  0.851514 -0.002605    0.910716
# 21            0.397681  0.022420    0.336572  0.846338 -0.004071    0.907890
# 11            0.397681  0.024218    0.335492  0.843621 -0.004489    0.906414
# 29            0.397681  0.010662    0.329811  0.829336 -0.002194    0.898730
# 27            0.397681  0.034268    0.327660  0.823928 -0.007323    0.895856
# 35            0.397681  0.031481    0.324560  0.816132 -0.007093    0.891743
# 15            0.397681  0.022744    0.324027  0.814791 -0.005170    0.891040
# 41            0.397681  0.020748    0.323159  0.812609 -0.004785    0.889897
# 39            0.242934  0.016199    0.252310  1.038595  0.000602    1.012540
# 24            0.242934  0.023732    0.226921  0.934085 -0.001675    0.979287

# %% [markdown]
# **Not good result. Associations are mostly for categories 'Supermarket', 'Metro Station' and 'Square'.**

# %% [markdown]
# #### Analysis 2: Per User between Categories of Points of Interest
#
# We try to find if there is an association between the categories of points of interest a user visits.

# %%
data = visits[['user_id', 'title', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
data = data.groupby(by=['user_id', 'title']).count().reset_index()
data['sum'] = 1
perday = data.groupby(['user_id', 'title'])['sum'].sum().unstack().reset_index().fillna(0).set_index('user_id')
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
frequent_itemsets = apriori(perday, min_support=0.7, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules.head(15)
# Out:
#                                             antecedents  \
# 1769       (Metro Station, Square, Cafe, Women's Store)
# 362                   (Cultural Center, Clothing Store)
# 1353             (Metro Station, Square, Women's Store)
# 1101                        (Park, Women's Store, Cafe)
# 1889  (Metro Station, Square, Beach, Shopping Mall, ...
# 611                       (Metro Station, Cafe, Bakery)
# 158                            (Cultural Center, Beach)
# 1893  (Metro Station, Beach, Shopping Mall, Park, Cu...
# 1800                (Park, Square, Cafe, Women's Store)
# 1905  (Metro Station, Cultural Center, Beach, Shoppi...
# 1691                  (Metro Station, Cafe, Home Store)
# 1366                 (Supermarket, Women's Store, Park)
# 1129                      (Square, Women's Store, Cafe)
# 1367                      (Park, Square, Women's Store)
# 639                     (Metro Station, Square, Bakery)
#
#                 consequents  antecedent support  consequent support   support  \
# 1769          (Supermarket)            0.704478            0.858706  0.704478
# 362           (Supermarket)            0.701493            0.858706  0.701493
# 1353          (Supermarket)            0.705473            0.858706  0.705473
# 1101          (Supermarket)            0.700498            0.858706  0.700498
# 1889                 (Park)            0.700498            0.812935  0.700498
# 611           (Supermarket)            0.703483            0.858706  0.703483
# 158                  (Park)            0.769154            0.812935  0.769154
# 1893               (Square)            0.700498            0.800995  0.700498
# 1800          (Supermarket)            0.700498            0.858706  0.700498
# 1905         (Park, Square)            0.700498            0.768159  0.700498
# 1691  (Supermarket, Square)            0.700498            0.743284  0.700498
# 1366               (Square)            0.701493            0.800995  0.701493
# 1129          (Supermarket)            0.707463            0.858706  0.707463
# 1367          (Supermarket)            0.701493            0.858706  0.701493
# 639           (Supermarket)            0.703483            0.858706  0.703483
#
#       confidence      lift  leverage  conviction
# 1769         1.0  1.164542  0.099538         inf
# 362          1.0  1.164542  0.099116         inf
# 1353         1.0  1.164542  0.099679         inf
# 1101         1.0  1.164542  0.098976         inf
# 1889         1.0  1.230110  0.131038         inf
# 611          1.0  1.164542  0.099398         inf
# 158          1.0  1.230110  0.143882         inf
# 1893         1.0  1.248447  0.139402         inf
# 1800         1.0  1.164542  0.098976         inf
# 1905         1.0  1.301813  0.162404         inf
# 1691         1.0  1.345382  0.179829         inf
# 1366         1.0  1.248447  0.139601         inf
# 1129         1.0  1.164542  0.099960         inf
# 1367         1.0  1.164542  0.099116         inf
# 639          1.0  1.164542  0.099398         inf

# %% [markdown]
# **Too many results that can not be interpreted in a useful way.**

# %% [markdown]
# #### Analysis 3: Per Day & Per User  between Points of Interest
#
# We try to find if there is an association between the points of interest a user visits during the same day.

# %%
visits['code'] = visits['user_id'] + visits['created']
data = visits[['code', 'poi_id', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
data = data.groupby(by=['code', 'poi_id']).count().reset_index()
data['sum'] = 1
perday = data.groupby(['code', 'poi_id'])['sum'].sum().unstack().reset_index().fillna(0).set_index('code')
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
frequent_itemsets = apriori(perday, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.01)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# **No results**

# %% [markdown]
# ####  Analysis 4: Per Day & Per User between Categories of Points of Interest while taking into account visits in multiple points of interest that belong in the same category
# We try to find if there is an association between the categories of points of interest a user visits during the same day. In this specific analysis we want to see if users often visit points of interest that belong in the same category together.

# %%
visits['code'] = visits['user_id'] + visits['created']
data = visits[['code', 'title', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
data = data.groupby(by=['code', 'title']).count().reset_index()
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
visits['code'] = visits['user_id'] + visits['created']
data = visits[['code', 'title', 'id']]

# %%
data = data.groupby(by=['code', 'title']).count().reset_index()
data['sum'] = 1

# %%
perday = data.groupby(['code', 'title'])['sum'].sum().unstack().reset_index().fillna(0).set_index('code')
frequent_itemsets = apriori(perday, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.6)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules.head(15)
# Out:
#             antecedents    consequents  antecedent support  \
# 43          (Pet Store)  (Supermarket)            0.036030
# 3              (Bakery)  (Supermarket)            0.052697
# 23  (Electronics Store)  (Supermarket)            0.046620
# 61      (Women's Store)  (Supermarket)            0.092467
# 45         (Shoe Store)  (Supermarket)            0.043042
# 25                (Gym)  (Supermarket)            0.044121
# 29         (Home Store)  (Supermarket)            0.066613
# 17     (Clothing Store)  (Supermarket)            0.072186
# 37             (Museum)  (Supermarket)            0.032327
# 35      (Metro Station)  (Supermarket)            0.104585
# 49      (Shopping Mall)  (Supermarket)            0.096997
# 21    (Cultural Center)  (Supermarket)            0.070191
# 59         (University)  (Supermarket)            0.064204
# 13               (Cafe)  (Supermarket)            0.114114
# 53             (Square)  (Supermarket)            0.242934
#
#     consequent support   support  confidence      lift  leverage  conviction
# 43            0.397681  0.014168    0.393214  0.988767 -0.000161    0.992638
# 3             0.397681  0.019597    0.371887  0.935139 -0.001359    0.958934
# 23            0.397681  0.017296    0.370999  0.932906 -0.001244    0.957581
# 61            0.397681  0.032291    0.349213  0.878123 -0.004482    0.925524
# 45            0.397681  0.014851    0.345029  0.867604 -0.002266    0.919613
# 25            0.397681  0.014941    0.338631  0.851514 -0.002605    0.910716
# 29            0.397681  0.022420    0.336572  0.846338 -0.004071    0.907890
# 17            0.397681  0.024218    0.335492  0.843621 -0.004489    0.906414
# 37            0.397681  0.010662    0.329811  0.829336 -0.002194    0.898730
# 35            0.397681  0.034268    0.327660  0.823928 -0.007323    0.895856
# 49            0.397681  0.031481    0.324560  0.816132 -0.007093    0.891743
# 21            0.397681  0.022744    0.324027  0.814791 -0.005170    0.891040
# 59            0.397681  0.020748    0.323159  0.812609 -0.004785    0.889897
# 13            0.397681  0.034880    0.305656  0.768597 -0.010501    0.867466
# 53            0.397681  0.072690    0.299216  0.752401 -0.023921    0.859493

# %% [markdown]
# **Similar results with those of the 1st analysis.**

# %% [markdown]
# #### Analysis 5: Per Day & Per User between Categories of Points of Interest, only for consistent clients
#
# We try to find if there is an association between the categories of points of interest a consistent user visits during the same day.

# %%
visits['code'] = visits['user_id'] + visits['created']
visits = pd.merge(visits,
                  user_cons,
                  how = 'left',
                  on = 'user_id')

# %%
visits_cons = visits[visits['consistency'] == 'consistent']
data = visits_cons[['code', 'title', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data = data.groupby(by=['code', 'title']).count().reset_index()
data['sum'] = 1

# %%
perday = data.groupby(['code', 'title'])['sum'].sum().unstack().reset_index().fillna(0).set_index('code')

# %%
frequent_itemsets = apriori(perday, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.8)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules.head(15)
# Out:
#             antecedents    consequents  antecedent support  \
# 31          (Pet Store)  (Supermarket)            0.036448
# 17  (Electronics Store)  (Supermarket)            0.046616
# 3              (Bakery)  (Supermarket)            0.052907
# 43      (Women's Store)  (Supermarket)            0.093671
# 33         (Shoe Store)  (Supermarket)            0.043196
# 19                (Gym)  (Supermarket)            0.044659
# 21         (Home Store)  (Supermarket)            0.067501
# 11     (Clothing Store)  (Supermarket)            0.072859
# 15    (Cultural Center)  (Supermarket)            0.069183
# 27      (Metro Station)  (Supermarket)            0.103491
# 29             (Museum)  (Supermarket)            0.032717
# 35      (Shopping Mall)  (Supermarket)            0.097913
# 41         (University)  (Supermarket)            0.065306
# 39         (University)       (Square)            0.065306
# 1              (Bakery)       (Square)            0.052907
#
#     consequent support   support  confidence      lift  leverage  conviction
# 31            0.398054  0.014283    0.391872  0.984468 -0.000225    0.989833
# 17            0.398054  0.017245    0.369949  0.929394 -0.001310    0.955392
# 3             0.398054  0.019513    0.368821  0.926561 -0.001547    0.953685
# 43            0.398054  0.032717    0.349278  0.877463 -0.004569    0.925042
# 33            0.398054  0.014959    0.346317  0.870024 -0.002235    0.920852
# 19            0.398054  0.015124    0.338657  0.850781 -0.002653    0.910187
# 21            0.398054  0.022750    0.337036  0.846709 -0.004119    0.907962
# 11            0.398054  0.024524    0.336596  0.845604 -0.004478    0.907360
# 15            0.398054  0.023134    0.334391  0.840063 -0.004404    0.904353
# 27            0.398054  0.034546    0.333805  0.838591 -0.006649    0.903557
# 29            0.398054  0.010845    0.331470  0.832726 -0.002178    0.900402
# 35            0.398054  0.031967    0.326485  0.820202 -0.007008    0.893738
# 41            0.398054  0.021104    0.323159  0.811846 -0.004891    0.889346
# 39            0.244527  0.016477    0.252310  1.031828  0.000508    1.010409
# 1             0.244527  0.011832    0.223643  0.914594 -0.001105    0.973100

# %% [markdown]
# **Close results with those of the 1st analysis.**

# %% [markdown]
# #### Analysis 5: Per Day & Per User between Points of Interest, only for consistent clients
#
# We try to find if there is an association between the points of interest a consistent user visits during the same day.

# %%
visits['code'] = visits['user_id'] + visits['created']
visits = pd.merge(visits,
                  user_cons,
                  how = 'left',
                  on = 'user_id')

# %%
visits_cons = visits[visits['consistency'] == 'inconsistent']
data = visits[['user_id', 'poi_id', 'id']]
data.rename(columns= {'id': 'sum'}, inplace = True)
data = data.groupby(by=['user_id', 'poi_id']).count().reset_index()
data['sum'] = 1
perday = data.groupby(['user_id', 'poi_id'])['sum'].sum().unstack().reset_index().fillna(0).set_index('user_id')
# Out:
# c:\users\theod\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
frequent_itemsets = apriori(perday, min_support=0.7, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.sort_values(by = 'confidence', ascending = False, inplace = True)

# %%
rules
# Out:
#                               antecedents  \
# 3  (581ce08d-b424-45ef-a2c2-f328989a52b1)
# 0  (373636b6-6361-48e8-a02d-2de41d80edb6)
# 4  (373636b6-6361-48e8-a02d-2de41d80edb6)
# 2  (0f65c381-51dc-40a6-b306-1fc109e1f62c)
# 5  (581ce08d-b424-45ef-a2c2-f328989a52b1)
# 1  (0f65c381-51dc-40a6-b306-1fc109e1f62c)
#
#                               consequents  antecedent support  \
# 3  (0f65c381-51dc-40a6-b306-1fc109e1f62c)            0.757214
# 0  (0f65c381-51dc-40a6-b306-1fc109e1f62c)            0.722388
# 4  (581ce08d-b424-45ef-a2c2-f328989a52b1)            0.722388
# 2  (581ce08d-b424-45ef-a2c2-f328989a52b1)            0.768159
# 5  (373636b6-6361-48e8-a02d-2de41d80edb6)            0.757214
# 1  (373636b6-6361-48e8-a02d-2de41d80edb6)            0.768159
#
#    consequent support   support  confidence      lift  leverage  conviction
# 3            0.768159  0.747264    0.986859  1.284707  0.165603   17.643085
# 0            0.768159  0.712438    0.986226  1.283882  0.157529   16.831642
# 4            0.757214  0.706468    0.977961  1.291526  0.159465   11.016418
# 2            0.757214  0.747264    0.972798  1.284707  0.165603    8.925278
# 5            0.722388  0.706468    0.932983  1.291526  0.159465    4.142406
# 1            0.722388  0.712438    0.927461  1.283882  0.157529    3.827079

# %% [markdown]
# **The associations are only between points of interest "Flisvos Park", "Palaio Faliro Beach" and "Stavros Niarchos Foundation".**
